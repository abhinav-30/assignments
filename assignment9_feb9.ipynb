# %%
# Q1, Create a vehicle class with an init method having instance variables as name_of_vehicle, max_speedand average_of_vehicle.

class vehicle:
    def __init__(self,name,speed,av):
        self.name_of_vehicle = name
        self.max_speed = speed
        self.average_of_vehicle = av

# %%
#Q2.Create a child class car from the vehicle class created in Que 1, which will inherit the vehicle class.
#Create a method named seating_capacity which takes capacity as an argument and returns the name of the vehicle and 
#its seating capacity.

class car(vehicle):
    def seating_capacity(self,capacity):
        cap=capacity
        return self.name_of_vehicle,cap

# %%
car1=car('jeep',50,10)

# %%
car1.seating_capacity(5)
# Out:
# ('jeep', 5)

# %%
Q3. What is multiple inheritance? Write a python code to demonstrate multiple inheritance.

Multiple inheritance is a feature of object-oriented programming where a class can inherit attributes and methods from multiple parent classes.

# %%
class A:
    def method1(self):
        print("method of class A")

class B:
    def method2(self):
        print("method of class B")

class C(A,B):
    def method3(self):
        print("method of class C")

# %%
c = C()

# %%
c.method1()
# Out:
# method of class A

# %%
c.method2()
# Out:
# method of class B

# %%
Q4. What are getter and setter in python? Create a class and create a getter and a setter method in this
class.

In Python, getters and setters are methods used to access and modify the values of instance variables.
They are used to control access to the variables and enforce data encapsulation.
Getter methods are used to retrieve the value of an instance variable, while setter methods are used to set or modify the value of an instance variable.

# %%
class Person:
    def __init__(self, name, age):
        self._name = name
        self._age = age

    def get_name(self):
        return self._name

    def set_name(self, name):
        self._name = name

    def get_age(self):
        return self._age

    def set_age(self, age):
        self._age = age

# %%
Q5.What is method overriding in python? Write a python code to demonstrate method overriding.

When a child class method  provides its own implementation of the parent class method of the same name, parameters and return type, it is known as method overriding.

There are two prerequisite conditions for Method overriding:
    
Inheritance should be present in the code, method overriding cannot be performed in the same class, and overriding can only be executed when a child class is derived through inheritance.
The child class method  should have the same name and the same number of parameters as the parent class.

# %%
class Animal:
    def sound(self):
        print("sound of animal")

class dog(Animal):
    def sound(self):
        print(" dog barks")
